# %%
import pandas as pd

sample_data = pd.read_excel('쇼핑몰프로젝트DATA.xlsx')
sample_data.head()
# Out:
#    CRI_YM                   TAG 평일휴일 요일       시간대 성별    연령대  건수합계  \
# 0    2019  생활/취미/사무용품/인테리어/골프용품   평일  목  B.06-10시  F  A.2O대   291
# 1    2020  생활/취미/사무용품/인테리어/골프용품   평일  월  D.14-18시  M  C.4O대  6225
# 2    2019  생활/취미/사무용품/인테리어/골프용품   휴일  일  F.22-02시  M  B.3O대    51
# 3    2021                패션/화장품   휴일  일  D.14-18시  F  C.4O대  3564
# 4    2020  생활/취미/사무용품/인테리어/골프용품   평일  월  C.10-14시  F  D.5O대  1101
#
#    인터넷 쇼핑 이용자 비율 (%)  월 평균 구매빈도-1회 미만 (%)  월 평균 구매빈도-1~2회 미만 (%)  \
# 0               98.7                 10.9                   18.6
# 1               66.7                 28.3                   17.9
# 2               86.3                 14.6                   21.3
# 3               89.8                  9.3                   14.9
# 4               46.3                 28.2                   14.1
#
#    월 평균 구매빈도-2~3회 미만 (%)  월 평균 구매빈도-3회 이상 (%)  월 평균 구매빈도-평균 (회)
# 0                   22.8                 47.7               3.3
# 1                   21.0                 32.8               2.9
# 2                   22.4                 41.7               2.9
# 3                   17.6                 58.2               5.3
# 4                   20.2                 37.4               3.4

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19997 entries, 0 to 19996
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CRI_YM                 19997 non-null  int64
#  1   TAG                    19997 non-null  object
#  2   평일휴일                   19997 non-null  object
#  3   요일                     19997 non-null  object
#  4   시간대                    19997 non-null  object
#  5   성별                     19997 non-null  object
#  6   연령대                    19997 non-null  object
#  7   건수합계                   19997 non-null  int64
#  8   인터넷 쇼핑 이용자 비율 (%)      19997 non-null  float64
#  9   월 평균 구매빈도-1회 미만 (%)    19997 non-null  float64
#  10  월 평균 구매빈도-1~2회 미만 (%)  19997 non-null  float64
#  11  월 평균 구매빈도-2~3회 미만 (%)  19997 non-null  float64
#  12  월 평균 구매빈도-3회 이상 (%)    19997 non-null  float64
#  13  월 평균 구매빈도-평균 (회)       19997 non-null  float64
# dtypes: float64(6), int64(2), object(6)
# memory usage: 2.1+ MB

# %%
print(sample_data['TAG'].value_counts())
print('---------------------------------')
print(sample_data['평일휴일'].value_counts())
print('---------------------------------')
print(sample_data['요일'].value_counts())
print('---------------------------------')
print(sample_data['시간대'].value_counts())
print('---------------------------------')
print(sample_data['성별'].value_counts())
print('---------------------------------')
print(sample_data['연령대'].value_counts())
# Out:
# 생활/취미/사무용품/인테리어/골프용품    12232
# 패션/화장품                   4661
# 식료품                      1560
# 애완용품                     1544
# Name: TAG, dtype: int64
# ---------------------------------
# 평일    11625
# 휴일     8372
# Name: 평일휴일, dtype: int64
# ---------------------------------
# 수    3833
# 화    3077
# 금    3072
# 월    3044
# 목    2331
# 일    2321
# 토    2319
# Name: 요일, dtype: int64
# ---------------------------------
# D.14-18시    3369
# E.18-22시    3369
# F.22-02시    3365
# C.10-14시    3362
# B.06-10시    3342
# A.02-06시    3190
# Name: 시간대, dtype: int64
# ---------------------------------
# M    10017
# F     9980
# Name: 성별, dtype: int64
# ---------------------------------
# C.4O대      4051
# B.3O대      4043
# D.5O대      4038
# A.2O대      3971
# E.60대이상    3894
# Name: 연령대, dtype: int64

# %%
#pd.get_dummies(data = sample_data)

# %%
#Object 형을 수치화 
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
sample_data['TAG'] = le.fit_transform(sample_data['TAG'])
sample_data['평일휴일'] = le.fit_transform(sample_data['평일휴일'])
sample_data['요일'] = le.fit_transform(sample_data['요일'])
sample_data['시간대'] = le.fit_transform(sample_data['시간대'])
sample_data['성별'] = le.fit_transform(sample_data['성별'])
sample_data['연령대'] = le.fit_transform(sample_data['연령대'])


print(sample_data.head())
# Out:
#    CRI_YM  TAG  평일휴일  요일  시간대  성별  연령대  건수합계  인터넷 쇼핑 이용자 비율 (%)  \
# 0    2019    0     0   1    1   0    0   291               98.7
# 1    2020    0     0   3    3   1    2  6225               66.7
# 2    2019    0     1   4    5   1    1    51               86.3
# 3    2021    3     1   4    3   0    2  3564               89.8
# 4    2020    0     0   3    2   0    3  1101               46.3
#
#    월 평균 구매빈도-1회 미만 (%)  월 평균 구매빈도-1~2회 미만 (%)  월 평균 구매빈도-2~3회 미만 (%)  \
# 0                 10.9                   18.6                   22.8
# 1                 28.3                   17.9                   21.0
# 2                 14.6                   21.3                   22.4
# 3                  9.3                   14.9                   17.6
# 4                 28.2                   14.1                   20.2
#
#    월 평균 구매빈도-3회 이상 (%)  월 평균 구매빈도-평균 (회)
# 0                 47.7               3.3
# 1                 32.8               2.9
# 2                 41.7               2.9
# 3                 58.2               5.3
# 4                 37.4               3.4

# %%
#Tag를 기준으로 확률을 높여보자! 
y = sample_data['TAG']
print(y)
#
y = y.values.reshape(-1,1)
print(y)

y = pd.DataFrame(y)

X= pd.DataFrame(sample_data, columns=['CRI_YM','평일휴일','요일','시간대','성별','연령대','건수합계','인터넷 쇼핑 이용자 비율 (%)','월 평균 구매빈도-1회 미만 (%)','월 평균 구매빈도-1~2회 미만 (%)','월 평균 구매빈도-2~3회 미만 (%)','월 평균 구매빈도-3회 이상 (%)','월 평균 구매빈도-평균 (회)'])
print(X)
# Out:
# 0        0
# 1        0
# 2        0
# 3        3
# 4        0
#         ..
# 19992    3
# 19993    0
# 19994    3
# 19995    0
# 19996    0
# Name: TAG, Length: 19997, dtype: int64
# [[0]
#  [0]
#  [0]
#  ...
#  [3]
#  [0]
#  [0]]
#        CRI_YM  평일휴일  요일  시간대  성별  연령대  건수합계  인터넷 쇼핑 이용자 비율 (%)  \
# 0        2019     0   1    1   0    0   291               98.7
# 1        2020     0   3    3   1    2  6225               66.7
# 2        2019     1   4    5   1    1    51               86.3
# 3        2021     1   4    3   0    2  3564               89.8
# 4        2020     0   3    2   0    3  1101               46.3
# ...       ...   ...  ..  ...  ..  ...   ...                ...
# 19992    2019     0   3    5   1    2  2470               66.8
# 19993    2020     0   0    3   0    2   107               76.8
# 19994    2021     0   6    4   1    1   603               91.5
# 19995    2021     0   6    2   0    4   415               31.7
# 19996    2019     0   1    2   1    2   580               66.8
#
#        월 평균 구매빈도-1회 미만 (%)  월 평균 구매빈도-1~2회 미만 (%)  월 평균 구매빈도-2~3회 미만 (%)  \
# 0                     10.9                   18.6                   22.8
# 1                     28.3                   17.9                   21.0
# 2                     14.6                   21.3                   22.4
# 3                      9.3                   14.9                   17.6
# 4                     28.2                   14.1                   20.2
# ...                    ...                    ...                    ...
# 19992                 17.1                   23.2                   20.0
# 19993                 24.1                   12.9                   17.6
# 19994                 10.6                   15.6                   18.5
# 19995                 11.0                   18.7                   19.6
# 19996                 17.1                   23.2                   20.0
#
#        월 평균 구매빈도-3회 이상 (%)  월 평균 구매빈도-평균 (회)
# 0                     47.7               3.3
# 1                     32.8               2.9
# 2                     41.7               2.9
# 3                     58.2               5.3
# 4                     37.4               3.4
# ...                    ...               ...
# 19992                 39.7               2.9
# 19993                 45.4               3.8
# 19994                 55.3               4.9
# 19995                 50.7               4.1
# 19996                 39.7               2.9
#
# [19997 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
# %matplotlib inline 

from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings('ignore')

#DecisionTree Classifier 생성 
dt_clf = DecisionTreeClassifier(random_state=156)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 11)

#DecisionTreeClassifier 학습 
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=156)
